# %% [markdown]
# ## Antrophic Economic Index

# %% [markdown]
# Download using `hf download Anthropic/EconomicIndex --repo-type dataset --local-dir ./EconomicIndex`

# %% [markdown]
# ## Wildchat

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("AIcell/MOSSBench", "oversensitivity")
# Out:
# ...
# Resolving data files:   0%|          | 0/301 [00:00<?, ?it/s]
# ...
# images/130.png:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# images/126.png:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# images/132.png:   0%|          | 0.00/30.9k [00:00<?, ?B/s]
# images/12.png:   0%|          | 0.00/1.73M [00:00<?, ?B/s]
# images/11.png:   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# images/128.png:   0%|          | 0.00/717k [00:00<?, ?B/s]
# images/125.png:   0%|          | 0.00/836k [00:00<?, ?B/s]
# images/127.png:   0%|          | 0.00/657k [00:00<?, ?B/s]
# images/134.png:   0%|          | 0.00/2.71M [00:00<?, ?B/s]
# images/131.png:   0%|          | 0.00/6.37k [00:00<?, ?B/s]
# images/13.png:   0%|          | 0.00/3.81M [00:00<?, ?B/s]
# images/120.png:   0%|          | 0.00/1.45M [00:00<?, ?B/s]
# images/129.png:   0%|          | 0.00/1.45M [00:00<?, ?B/s]
# images/136.png:   0%|          | 0.00/278k [00:00<?, ?B/s]
# images/135.png:   0%|          | 0.00/1.18M [00:00<?, ?B/s]
# ...

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'pid', 'question', 'image', 'short description', 'description', 'metadata_over', 'metadata_human', 'metadata_child', 'metadata_syn', 'metadata_ocr', 'metadata_harm'],
#     num_rows: 300
# })
